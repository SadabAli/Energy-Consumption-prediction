# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\alisa\OneDrive\Desktop\Energy Consumption prediction\Electricity consumption.csv")
data.sample(5)
# Out:
#        Unnamed: 0       Start time UTC         End time UTC  \
# 17017       17017  2017-12-09 08:00:00  2017-12-09 09:00:00
# 18165       18165  2018-01-26 06:00:00  2018-01-26 07:00:00
# 7369         7369  2016-11-02 13:00:00  2016-11-02 14:00:00
# 32290       32290  2019-09-06 07:00:00  2019-09-06 08:00:00
# 4134         4134  2016-06-21 11:00:00  2016-06-21 12:00:00
#
#        Electricity consumption in Odisha Start time IST UTC+05:30  \
# 17017                            10016.0      2017-12-09 13:30:00
# 18165                            11945.0      2018-01-26 11:30:00
# 7369                             11144.0      2016-11-02 18:30:00
# 32290                             9043.0      2019-09-06 12:30:00
# 4134                              8434.0      2016-06-21 16:30:00
#
#       End time IST UTC+05:30
# 17017    2017-12-09 14:30:00
# 18165    2018-01-26 12:30:00
# 7369     2016-11-02 19:30:00
# 32290    2019-09-06 13:30:00
# 4134     2016-06-21 17:30:00

# %%
data = data.drop(columns=['Unnamed: 0'])

# %%
data
# Out:
#             Start time UTC         End time UTC  \
# 0      2015-12-31 21:00:00  2015-12-31 22:00:00
# 1      2015-12-31 22:00:00  2015-12-31 23:00:00
# 2      2015-12-31 23:00:00  2016-01-01 00:00:00
# 3      2016-01-01 00:00:00  2016-01-01 01:00:00
# 4      2016-01-01 01:00:00  2016-01-01 02:00:00
# ...                    ...                  ...
# 52961  2021-12-31 16:00:00  2021-12-31 17:00:00
# 52962  2021-12-31 17:00:00  2021-12-31 18:00:00
# 52963  2021-12-31 18:00:00  2021-12-31 19:00:00
# 52964  2021-12-31 19:00:00  2021-12-31 20:00:00
# 52965  2021-12-31 20:00:00  2021-12-31 21:00:00
#
#        Electricity consumption in Odisha Start time IST UTC+05:30  \
# 0                                10800.0      2016-01-01 02:30:00
# 1                                10431.0      2016-01-01 03:30:00
# 2                                10005.0      2016-01-01 04:30:00
# 3                                 9722.0      2016-01-01 05:30:00
# ...

# %% [markdown]
# Data Exploration

# %%
print("Return first 5  row")
data.head(5)
# Out:
# Return first 5  row
#         Start time UTC         End time UTC  \
# 0  2015-12-31 21:00:00  2015-12-31 22:00:00
# 1  2015-12-31 22:00:00  2015-12-31 23:00:00
# 2  2015-12-31 23:00:00  2016-01-01 00:00:00
# 3  2016-01-01 00:00:00  2016-01-01 01:00:00
# 4  2016-01-01 01:00:00  2016-01-01 02:00:00
#
#    Electricity consumption in Odisha Start time IST UTC+05:30  \
# 0                            10800.0      2016-01-01 02:30:00
# 1                            10431.0      2016-01-01 03:30:00
# 2                            10005.0      2016-01-01 04:30:00
# 3                             9722.0      2016-01-01 05:30:00
# 4                             9599.0      2016-01-01 06:30:00
#
#   End time IST UTC+05:30
# 0    2016-01-01 03:30:00
# 1    2016-01-01 04:30:00
# 2    2016-01-01 05:30:00
# 3    2016-01-01 06:30:00
# 4    2016-01-01 07:30:00

# %%
print("return last 5 row")
data.tail(5)
# Out:
# return last 5 row
#             Start time UTC         End time UTC  \
# 52961  2021-12-31 16:00:00  2021-12-31 17:00:00
# 52962  2021-12-31 17:00:00  2021-12-31 18:00:00
# 52963  2021-12-31 18:00:00  2021-12-31 19:00:00
# 52964  2021-12-31 19:00:00  2021-12-31 20:00:00
# 52965  2021-12-31 20:00:00  2021-12-31 21:00:00
#
#        Electricity consumption in Odisha Start time IST UTC+05:30  \
# 52961                            11447.0      2021-12-31 21:30:00
# 52962                            11237.0      2021-12-31 22:30:00
# 52963                            10914.0      2021-12-31 23:30:00
# 52964                            10599.0      2022-01-01 00:30:00
# 52965                            10812.0      2022-01-01 01:30:00
#
#       End time IST UTC+05:30
# 52961    2021-12-31 22:30:00
# 52962    2021-12-31 23:30:00
# 52963    2022-01-01 00:30:00
# 52964    2022-01-01 01:30:00
# 52965    2022-01-01 02:30:00

# %%
print("printing 4 sample data")
data.sample(4)
# Out:
# printing 4 sample data
#             Start time UTC         End time UTC  \
# 17490  2017-12-29 02:00:00  2017-12-29 03:00:00
# 42530  2020-10-23 01:00:00  2020-10-23 02:00:00
# 26226  2018-12-28 03:00:00  2018-12-28 04:00:00
# 8541   2016-12-20 22:00:00  2016-12-20 23:00:00
#
#        Electricity consumption in Odisha Start time IST UTC+05:30  \
# 17490                             9591.0      2017-12-29 07:30:00
# 42530                             8054.0      2020-10-23 06:30:00
# 26226                            10054.0      2018-12-28 08:30:00
# 8541                              9583.0      2016-12-21 03:30:00
#
#       End time IST UTC+05:30
# 17490    2017-12-29 08:30:00
# 42530    2020-10-23 07:30:00
# 26226    2018-12-28 09:30:00
# 8541     2016-12-21 04:30:00

# %%
print("Finding the information about data")
data.info()
# Out:
# Finding the information about data
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52966 entries, 0 to 52965
# Data columns (total 5 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Start time UTC                     52966 non-null  object
#  1   End time UTC                       52966 non-null  object
#  2   Electricity consumption in Odisha  52966 non-null  float64
#  3   Start time IST UTC+05:30           52966 non-null  object
#  4   End time IST UTC+05:30             52966 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 2.0+ MB

# %%
#print("Descriptive statistics include those that summarize the central tendency, dispersion and shape of a dataset’s distribution, excluding NaN values.)
print(data.describe(), "\n")
# Out:
#        Electricity consumption in Odisha
# count                       52966.000000
# mean                         9488.750519
# std                          1576.241673
# min                          5341.000000
# 25%                          8322.000000
# 50%                          9277.000000
# 75%                         10602.000000
# max                         15105.000000

# %% [markdown]
# Feature Extraction

# %%
# Drop the specified columns
del data["Start time UTC"]
del data["End time UTC"]
del data["Start time IST UTC+05:30"]

# Rename columns with exact names
data.rename(columns={"End time IST UTC+05:30": "DateTime",
                     "Electricity consumption in Odisha": "Consumption"}, inplace=True)

# Display the first few rows to verify the changes
print(data.head(5))
# Out:
#    Consumption             DateTime
# 0      10800.0  2016-01-01 03:30:00
# 1      10431.0  2016-01-01 04:30:00
# 2      10005.0  2016-01-01 05:30:00
# 3       9722.0  2016-01-01 06:30:00
# 4       9599.0  2016-01-01 07:30:00

# %%
data
# Out:
#        Consumption             DateTime
# 0          10800.0  2016-01-01 03:30:00
# 1          10431.0  2016-01-01 04:30:00
# 2          10005.0  2016-01-01 05:30:00
# 3           9722.0  2016-01-01 06:30:00
# 4           9599.0  2016-01-01 07:30:00
# ...            ...                  ...
# 52961      11447.0  2021-12-31 22:30:00
# 52962      11237.0  2021-12-31 23:30:00
# 52963      10914.0  2022-01-01 00:30:00
# 52964      10599.0  2022-01-01 01:30:00
# 52965      10812.0  2022-01-01 02:30:00
#
# [52966 rows x 2 columns]

# %%
dataset = data
dataset["Month"] = pd.to_datetime(data["DateTime"]).dt.month
dataset["Year"] = pd.to_datetime(data["DateTime"]).dt.year
dataset["Date"] = pd.to_datetime(data["DateTime"]).dt.date
dataset["Time"] = pd.to_datetime(data["DateTime"]).dt.time
dataset["Week"] = pd.to_datetime(data["DateTime"]).dt.weekday
dataset["Day"] = pd.to_datetime(data["DateTime"]).dt.day_name()
dataset = data.set_index("DateTime")
dataset.index = pd.to_datetime(dataset.index)

# %%
dataset.head()
# Out:
#                      Consumption  Month  Year        Date      Time  Week  \
# DateTime
# 2016-01-01 03:30:00      10800.0      1  2016  2016-01-01  03:30:00     4
# 2016-01-01 04:30:00      10431.0      1  2016  2016-01-01  04:30:00     4
# 2016-01-01 05:30:00      10005.0      1  2016  2016-01-01  05:30:00     4
# 2016-01-01 06:30:00       9722.0      1  2016  2016-01-01  06:30:00     4
# 2016-01-01 07:30:00       9599.0      1  2016  2016-01-01  07:30:00     4
#
#                         Day
# DateTime
# 2016-01-01 03:30:00  Friday
# 2016-01-01 04:30:00  Friday
# 2016-01-01 05:30:00  Friday
# 2016-01-01 06:30:00  Friday
# 2016-01-01 07:30:00  Friday

# %%
dataset.tail()
# Out:
#                      Consumption  Month  Year        Date      Time  Week  \
# DateTime
# 2021-12-31 22:30:00      11447.0     12  2021  2021-12-31  22:30:00     4
# 2021-12-31 23:30:00      11237.0     12  2021  2021-12-31  23:30:00     4
# 2022-01-01 00:30:00      10914.0      1  2022  2022-01-01  00:30:00     5
# 2022-01-01 01:30:00      10599.0      1  2022  2022-01-01  01:30:00     5
# 2022-01-01 02:30:00      10812.0      1  2022  2022-01-01  02:30:00     5
#
#                           Day
# DateTime
# 2021-12-31 22:30:00    Friday
# 2021-12-31 23:30:00    Friday
# 2022-01-01 00:30:00  Saturday
# 2022-01-01 01:30:00  Saturday
# 2022-01-01 02:30:00  Saturday

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 52966 entries, 2016-01-01 03:30:00 to 2022-01-01 02:30:00
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Consumption  52966 non-null  float64
#  1   Month        52966 non-null  int32
#  2   Year         52966 non-null  int32
#  3   Date         52966 non-null  object
#  4   Time         52966 non-null  object
#  5   Week         52966 non-null  int32
#  6   Day          52966 non-null  object
# dtypes: float64(1), int32(3), object(3)
# memory usage: 2.6+ MB

# %%
dataset['Year'] , dataset.Year.unique()
# Out:
# (DateTime
#  2016-01-01 03:30:00    2016
#  2016-01-01 04:30:00    2016
#  2016-01-01 05:30:00    2016
#  2016-01-01 06:30:00    2016
#  2016-01-01 07:30:00    2016
#                         ...
#  2021-12-31 22:30:00    2021
#  2021-12-31 23:30:00    2021
#  2022-01-01 00:30:00    2022
#  2022-01-01 01:30:00    2022
#  2022-01-01 02:30:00    2022
#  Name: Year, Length: 52966, dtype: int32,
#  array([2016, 2017, 2018, 2019, 2020, 2021, 2022]))

# %%
dataset.head()
# Out:
#                      Consumption  Month  Year        Date      Time  Week  \
# DateTime
# 2016-01-01 03:30:00      10800.0      1  2016  2016-01-01  03:30:00     4
# 2016-01-01 04:30:00      10431.0      1  2016  2016-01-01  04:30:00     4
# 2016-01-01 05:30:00      10005.0      1  2016  2016-01-01  05:30:00     4
# 2016-01-01 06:30:00       9722.0      1  2016  2016-01-01  06:30:00     4
# 2016-01-01 07:30:00       9599.0      1  2016  2016-01-01  07:30:00     4
#
#                         Day
# DateTime
# 2016-01-01 03:30:00  Friday
# 2016-01-01 04:30:00  Friday
# 2016-01-01 05:30:00  Friday
# 2016-01-01 06:30:00  Friday
# 2016-01-01 07:30:00  Friday

# %%
dataset[69:75]
# Out:
#                      Consumption  Month  Year        Date      Time  Week  \
# DateTime
# 2016-01-04 00:30:00      11756.0      1  2016  2016-01-04  00:30:00     0
# 2016-01-04 01:30:00      11475.0      1  2016  2016-01-04  01:30:00     0
# 2016-01-04 02:30:00      11721.0      1  2016  2016-01-04  02:30:00     0
# 2016-01-04 03:30:00      11626.0      1  2016  2016-01-04  03:30:00     0
# 2016-01-04 04:30:00      11253.0      1  2016  2016-01-04  04:30:00     0
# 2016-01-04 05:30:00      10925.0      1  2016  2016-01-04  05:30:00     0
#
#                         Day
# DateTime
# 2016-01-04 00:30:00  Monday
# 2016-01-04 01:30:00  Monday
# 2016-01-04 02:30:00  Monday
# 2016-01-04 03:30:00  Monday
# 2016-01-04 04:30:00  Monday
# 2016-01-04 05:30:00  Monday

# %%
dataset[69:-123]
# Out:
#                      Consumption  Month  Year        Date      Time  Week  \
# DateTime
# 2016-01-04 00:30:00      11756.0      1  2016  2016-01-04  00:30:00     0
# 2016-01-04 01:30:00      11475.0      1  2016  2016-01-04  01:30:00     0
# 2016-01-04 02:30:00      11721.0      1  2016  2016-01-04  02:30:00     0
# 2016-01-04 03:30:00      11626.0      1  2016  2016-01-04  03:30:00     0
# 2016-01-04 04:30:00      11253.0      1  2016  2016-01-04  04:30:00     0
# ...                          ...    ...   ...         ...       ...   ...
# 2021-12-26 19:30:00      12212.0     12  2021  2021-12-26  19:30:00     6
# 2021-12-26 20:30:00      12495.0     12  2021  2021-12-26  20:30:00     6
# 2021-12-26 21:30:00      12550.0     12  2021  2021-12-26  21:30:00     6
# 2021-12-26 22:30:00      12622.0     12  2021  2021-12-26  22:30:00     6
# 2021-12-26 23:30:00      12574.0     12  2021  2021-12-26  23:30:00     6
#
#                         Day
# DateTime
# 2016-01-04 00:30:00  Monday
# ...

# %% [markdown]
# By assuming week starts on Mondey and ends on Sunday.
#
# The closest start would be on Monday 2016-01-04
#
# The closest end would be on sunday 22021-12-26
#
# So we should omit first 69 rows and last 123 rows.

# %%
dataset=dataset[69:-123]

# %%
print(dataset.head(2))
print('-------------------------')
print(dataset.tail(2))
# Out:
#                      Consumption  Month  Year        Date      Time  Week  \
# DateTime
# 2016-01-04 00:30:00      11756.0      1  2016  2016-01-04  00:30:00     0
# 2016-01-04 01:30:00      11475.0      1  2016  2016-01-04  01:30:00     0
#
#                         Day
# DateTime
# 2016-01-04 00:30:00  Monday
# 2016-01-04 01:30:00  Monday
# -------------------------
#                      Consumption  Month  Year        Date      Time  Week  \
# DateTime
# 2021-12-26 22:30:00      12622.0     12  2021  2021-12-26  22:30:00     6
# 2021-12-26 23:30:00      12574.0     12  2021  2021-12-26  23:30:00     6
#
#                         Day
# DateTime
# 2021-12-26 22:30:00  Sunday
# 2021-12-26 23:30:00  Sunday

# %% [markdown]
# Data Viz

# %%
sns.lineplot(data = dataset , x=dataset['Year'] , y=dataset['Consumption'])
plt.title("Electricity consumption in Odisha 2016-2021")
plt.xlabel("Year")
plt.ylabel("Energy in MW")
plt.grid(True)
plt.legend()
# Out:
# C:\Users\alisa\AppData\Local\Temp\ipykernel_24340\985028326.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# The graph shows electricity consumption in Odisha from 2016 to 2021. Consumption peaked in 2018, dropped in 2020, and rose again by 2021. This indicates fluctuating energy usage over these years.

# %%
plt.figure(figsize=(15,10))
plt.plot(dataset["Consumption"])

# %% [markdown]
# Overall, the graph shows fluctuating energy usage over these years.
# This indicates that electricity usage in Odisha has varied significantly, possibly due to factors like economic activities, weather conditions, or policy changes.

# %%
from matplotlib import style

fig = plt.figure(figsize = (30,30))

ax1 = fig.add_subplot(611)
ax2 = fig.add_subplot(612)
ax3 = fig.add_subplot(613)
ax4 = fig.add_subplot(614)
ax5 = fig.add_subplot(615)
ax6 = fig.add_subplot(616)

style.use("ggplot")

y_2016 = dataset.loc["2016"]["Consumption"].to_list()
x_2016 = dataset.loc["2016"]["Date"].to_list()
ax1.plot(x_2016, y_2016, color= "blue", linewidth= 1.7)

y_2017 = dataset.loc["2017"]["Consumption"].to_list()
x_2017 = dataset.loc["2017"]["Date"].to_list()
ax2.plot(x_2017, y_2017, color= "blue", linewidth= 1.7)

y_2018 = dataset.loc["2018"]["Consumption"].to_list()
x_2018 = dataset.loc["2018"]["Date"].to_list()
ax3.plot(x_2018, y_2018, color= "blue", linewidth= 1.7)

y_2019 = dataset.loc["2019"]["Consumption"].to_list()
x_2019 = dataset.loc["2019"]["Date"].to_list()
ax4.plot(x_2019, y_2019, color= "blue", linewidth= 1.7)

y_2020 = dataset.loc["2020"]["Consumption"].to_list()
x_2020 = dataset.loc["2020"]["Date"].to_list()
ax5.plot(x_2020, y_2020, color= "blue", linewidth= 1.7)

y_2021 = dataset.loc["2021"]["Consumption"].to_list()
x_2021 = dataset.loc["2021"]["Date"].to_list()
ax6.plot(x_2021, y_2021, color= "blue", linewidth= 1.7)

plt.rcParams["figure.figsize"] = (30, 15)
plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=2.5, wspace=0.4, hspace=0.4)
plt.title("Energy Consumption")
plt.xlabel("Date")
plt.ylabel("Energy in MW")
plt.grid(True, alpha=1)
plt.legend()
# Out:
# C:\Users\alisa\AppData\Local\Temp\ipykernel_24340\125561788.py:44: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# The pattern in the graph tells us that electricity consumption in Odisha is highly seasonal, with predictable changes across the year. This information is valuable for ensuring that the energy supply meets demand, for identifying opportunities to improve energy efficiency, and for understanding the impact of external events on energy use.

# %%
# Lets us see the Distribution off Energy Consumption so we have a idea about your Dataset a bit more
fig = plt.figure(figsize=(15, 10))
sns.histplot(dataset["Consumption"], kde=True)
plt.title("Energy Distribution")
plt.xlabel("Electricity Consumption")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Normal Distribution: The data follows a bell-shaped curve, indicating a normal distribution.
#
# Peak Consumption: The highest frequency of electricity consumption is around 9000 units.
#
# Variability: Consumption values further from 8000 units have lower frequencies, showing variability in energy demand.

# %%
fig = plt.figure(figsize = (15,10))
sns.boxplot(x=dataset["Month"], y=dataset["Consumption"], data= dataset , hue=dataset['Month'])
plt.title("Energy Consumption VS Month")
plt.xlabel("Month")
plt.grid(True, alpha=1)
plt.legend()

# %%
# i want to check energy consumption in hour

fig = plt.figure(figsize = (15,10))
sns.boxplot(data = dataset , x=dataset.index.hour, y=dataset['Consumption'] , color=".8", linecolor="#137", linewidth=.75)
plt.title("Energy Consumption VS Hour")
plt.xlabel("Hour")
plt.grid(True, alpha=1)
plt.legend()
# Out:
# C:\Users\alisa\AppData\Local\Temp\ipykernel_24340\1553339561.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
fig = plt.figure(figsize = (15,10))
sns.boxplot(data = dataset , x=dataset['Year'], y=dataset['Consumption'] , hue=dataset['Year'] , linecolor="#137", linewidth=.75)
plt.title("Energy Consumption VS Year")
plt.xlabel("Year")
plt.grid(True, alpha=1)
plt.legend()

# %%
dataset['Time']
# Out:
# DateTime
# 2016-01-04 00:30:00    00:30:00
# 2016-01-04 01:30:00    01:30:00
# 2016-01-04 02:30:00    02:30:00
# 2016-01-04 03:30:00    03:30:00
# 2016-01-04 04:30:00    04:30:00
#                          ...
# 2021-12-26 19:30:00    19:30:00
# 2021-12-26 20:30:00    20:30:00
# 2021-12-26 21:30:00    21:30:00
# 2021-12-26 22:30:00    22:30:00
# 2021-12-26 23:30:00    23:30:00
# Name: Time, Length: 52774, dtype: object

# %% [markdown]
# APPLYING LSTM MODEL (LONG SHORT TERM MEMORY)
#
# Train , Validation and Test Dataset

# %%
dataset.sample(1)
# Out:
#                      Consumption  Month  Year        Date      Time  Week  \
# DateTime
# 2018-11-27 13:30:00      11854.0     11  2018  2018-11-27  13:30:00     1
#
#                          Day
# DateTime
# 2018-11-27 13:30:00  Tuesday

# %%
# when your system is slow the you have to resample the data

# newdata = dataset.resample('D').mean()

# print("Old Data" , dataset.shape)
# print("New Data" , newdata.shape)

# %%
dataset.shape
# Out:
# (52774, 7)

# %%
dataset.sample(3)
# Out:
#                      Consumption  Month  Year        Date      Time  Week  \
# DateTime
# 2018-02-16 02:30:00      11611.0      2  2018  2018-02-16  02:30:00     4
# 2018-04-02 23:30:00      10863.0      4  2018  2018-04-02  23:30:00     0
# 2017-09-22 01:30:00       8679.0      9  2017  2017-09-22  01:30:00     4
#
#                         Day
# DateTime
# 2018-02-16 02:30:00  Friday
# 2018-04-02 23:30:00  Monday
# 2017-09-22 01:30:00  Friday

# %%
train = dataset.iloc[:52750]
test = dataset.iloc[52750:]

# %%
from sklearn.preprocessing import MinMaxScaler #Standardizes features by scaling each feature to a given range
scaler = MinMaxScaler()# use to convet the data in the scale of 0-1

# %%
dataset.head(),dataset.tail()
# Out:
# (                     Consumption  Month  Year        Date      Time  Week  \
#  DateTime
#  2016-01-04 00:30:00      11756.0      1  2016  2016-01-04  00:30:00     0
#  2016-01-04 01:30:00      11475.0      1  2016  2016-01-04  01:30:00     0
#  2016-01-04 02:30:00      11721.0      1  2016  2016-01-04  02:30:00     0
#  2016-01-04 03:30:00      11626.0      1  2016  2016-01-04  03:30:00     0
#  2016-01-04 04:30:00      11253.0      1  2016  2016-01-04  04:30:00     0
#
#                          Day
#  DateTime
#  2016-01-04 00:30:00  Monday
#  2016-01-04 01:30:00  Monday
#  2016-01-04 02:30:00  Monday
#  2016-01-04 03:30:00  Monday
#  2016-01-04 04:30:00  Monday  ,
#                       Consumption  Month  Year        Date      Time  Week  \
#  DateTime
#  2021-12-26 19:30:00      12212.0     12  2021  2021-12-26  19:30:00     6
#  2021-12-26 20:30:00      12495.0     12  2021  2021-12-26  20:30:00     6
# ...

# %%
train
# Out:
#                      Consumption  Month  Year        Date      Time  Week  \
# DateTime
# 2016-01-04 00:30:00      11756.0      1  2016  2016-01-04  00:30:00     0
# 2016-01-04 01:30:00      11475.0      1  2016  2016-01-04  01:30:00     0
# 2016-01-04 02:30:00      11721.0      1  2016  2016-01-04  02:30:00     0
# 2016-01-04 03:30:00      11626.0      1  2016  2016-01-04  03:30:00     0
# 2016-01-04 04:30:00      11253.0      1  2016  2016-01-04  04:30:00     0
# ...                          ...    ...   ...         ...       ...   ...
# 2021-12-25 19:30:00      11870.0     12  2021  2021-12-25  19:30:00     5
# 2021-12-25 20:30:00      12090.0     12  2021  2021-12-25  20:30:00     5
# 2021-12-25 21:30:00      12130.0     12  2021  2021-12-25  21:30:00     5
# 2021-12-25 22:30:00      12153.0     12  2021  2021-12-25  22:30:00     5
# 2021-12-25 23:30:00      12116.0     12  2021  2021-12-25  23:30:00     5
#
#                           Day
# DateTime
# ...

# %%
# Select only numeric columns to scale
numeric_columns = ['Consumption']
train_numeric = train[numeric_columns]
test_numeric = test[numeric_columns]

# Fit the scaler on training data and transform both train and test data
scaler.fit(train_numeric)
scaled_train = scaler.transform(train_numeric)
scaled_test = scaler.transform(test_numeric)

# %%
scaled_train[:10]
# Out:
# array([[0.65700533],
#        [0.62822614],
#        [0.65342073],
#        [0.64369111],
#        [0.60548955],
#        [0.57189676],
#        [0.54721426],
#        [0.5408644 ],
#        [0.55479312],
#        [0.59637444]])

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
# define generator
n_input = 3 # time steps like for 3 hour
n_features = 1 # now i am only using the "Electricity consumption" column as input
#tf.keras.preprocessing.sequence.TimeseriesGenerator(data,targets,length,batch_size=128)
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %% [markdown]
# The purpose of this code snippet is to prepare a dataset for training a neural network that learns from sequences of time series data. In this specific case, you're working with electricity consumption data over time.
#
# batch_size=1: This specifies how many samples per batch to use. Here, each batch will have one sequence.

# %%
X,y = generator[0] # generator is used to batches the input . This line accesses the first batch from the generator.
# X-> input , y-> prediction
print(f'Given the Array: \n{X.flatten()}') # X.flatten(): This flattens the 2D input array to a 1D array for easier reading.
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [0.65700533 0.62822614 0.65342073]
# Predict this y:
#  [[0.64369111]]

# %%
X.shape
# Out:
# (1, 3, 1)

# %% [markdown]
# (first dimension represents the batch size , econd dimension represents the number of time steps in the input sequence , features in each time step)

# %%
# # We do the same thing, but now instead for 12 Hr
# n_input = 12
# generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# define model
# model = Sequential()
# model.add(LSTM(100, activation='relu', input_shape=(n_input, n_features)))
# model.add(Dense(1))
# model.compile(optimizer='adam', loss='mse')

# %%
# model.summary()

# %%
# fit model
# model.fit(generator, epochs=10)

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# Check if generator is correctly initialized
print(type(generator))  # Should be <class 'tensorflow.keras.preprocessing.sequence.TimeseriesGenerator'>
# Out:
# <class 'keras.src.legacy.preprocessing.sequence.TimeseriesGenerator'>

# %%
# model.fit(generator,epochs=50)

# %%
import numpy as np
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# Example data
scaled_train = np.array(scaled_train)  # Ensure it's a numpy array

# # Define generator
# n_input = 12  # Number of time steps to look back
# n_features = scaled_train.shape[1]  # Number of features in your data
# generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

# Define model
model = Sequential() #The Sequential class is a linear stack of layers
model.add(LSTM(100, activation='tanh', input_shape=(n_input, n_features)))
model.add(Dense(1)) # dence layer 1 iss lia hai kun ki 1 value hi predict kar raha hu is lia
model.compile(optimizer='adam', loss='mse') #Mean Squared Error
# Out:
# c:\Users\alisa\OneDrive\Desktop\Energy Consumption prediction\env\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
from keras.callbacks import  EarlyStopping
callback =EarlyStopping(
    monitor="val_loss",
    min_delta=0.00001,
    patience=45,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
    start_from_epoch=0
)

# %%
# Print the model summary to check the structure
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                   │ (None, 100)            │        40,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 40,901 (159.77 KB)
#  Trainable params: 40,901 (159.77 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
import torch

print("Number of GPU: ", torch.cuda.device_count())
print("GPU Name: ", torch.cuda.get_device_name())


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Number of GPU:  1
# GPU Name:  NVIDIA GeForce RTX 3050 Laptop GPU
# Using device: cuda

# %%
model.fit(generator, epochs=50,callbacks=callback) # generator have both I/p and O/P
# Out:
# Epoch 1/50
#   113/52747 ━━━━━━━━━━━━━━━━━━━━ 1:11 1ms/step - loss: 0.0486
# c:\Users\alisa\OneDrive\Desktop\Energy Consumption prediction\env\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 52747/52747 ━━━━━━━━━━━━━━━━━━━━ 141s 3ms/step - loss: 0.0012
# Epoch 2/50
#    35/52747 ━━━━━━━━━━━━━━━━━━━━ 2:41 3ms/step - loss: 1.8608e-04
# c:\Users\alisa\OneDrive\Desktop\Energy Consumption prediction\env\Lib\site-packages\keras\src\callbacks\early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
#   current = self.get_monitor_value(logs)
# 52747/52747 ━━━━━━━━━━━━━━━━━━━━ 163s 3ms/step - loss: 4.3442e-04
# ...

# %%
# model.save('keras_model.h5')

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)
plt.xlabel("Epoch")
plt.ylabel("Mean Squared Error (MSE) calculated after each epoch")
plt.grid(True, alpha=1)
plt.legend()
# Out:
# C:\Users\alisa\AppData\Local\Temp\ipykernel_24340\663000630.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
test
# Out:
#                      Consumption  Month  Year        Date      Time  Week  \
# DateTime
# 2021-12-26 00:30:00      11936.0     12  2021  2021-12-26  00:30:00     6
# 2021-12-26 01:30:00      11659.0     12  2021  2021-12-26  01:30:00     6
# 2021-12-26 02:30:00      11964.0     12  2021  2021-12-26  02:30:00     6
# 2021-12-26 03:30:00      11875.0     12  2021  2021-12-26  03:30:00     6
# 2021-12-26 04:30:00      11558.0     12  2021  2021-12-26  04:30:00     6
# 2021-12-26 05:30:00      11252.0     12  2021  2021-12-26  05:30:00     6
# 2021-12-26 06:30:00      11151.0     12  2021  2021-12-26  06:30:00     6
# 2021-12-26 07:30:00      11165.0     12  2021  2021-12-26  07:30:00     6
# 2021-12-26 08:30:00      11206.0     12  2021  2021-12-26  08:30:00     6
# 2021-12-26 09:30:00      11296.0     12  2021  2021-12-26  09:30:00     6
# 2021-12-26 10:30:00      11477.0     12  2021  2021-12-26  10:30:00     6
# ...

# %%
last_3_hour = scaled_train[-3:]

# %%
last_3_hour = last_3_hour.reshape((1,n_input,n_features))

# %%
model.predict(last_3_hour)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# array([[0.6932079]], dtype=float32)

# %%
scaled_test[0]
# Out:
# array([0.67544039])

# %%
test_prediction = []  # Empty list to store predictions
first_eval_input = scaled_train[-n_input:]
current_input = first_eval_input.reshape(1, n_input, n_features)

for i in range(len(test)):
    current_prediction = model.predict(current_input)[0]
    
    # Append the prediction to the list
    test_prediction.append(current_prediction)
    
    # Optionally update current_input for the next prediction
    current_input = np.append(current_input[:,1:,:], [[current_prediction]], axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
test_prediction
# Out:
# [array([0.6932079], dtype=float32),
#  array([0.70028126], dtype=float32),
#  array([0.71236134], dtype=float32),
#  array([0.7249826], dtype=float32),
#  array([0.73507667], dtype=float32),
#  array([0.7419678], dtype=float32),
#  array([0.7466434], dtype=float32),
#  array([0.7506896], dtype=float32),
#  array([0.7553228], dtype=float32),
#  array([0.760824], dtype=float32),
#  array([0.76671875], dtype=float32),
#  array([0.7723702], dtype=float32),
#  array([0.7774218], dtype=float32),
#  array([0.7818806], dtype=float32),
#  array([0.7859621], dtype=float32),
#  array([0.7898861], dtype=float32),
#  array([0.7937561], dtype=float32),
#  array([0.7975551], dtype=float32),
#  array([0.80121255], dtype=float32),
#  array([0.8046719], dtype=float32),
#  array([0.80791926], dtype=float32),
#  array([0.81097436], dtype=float32),
#  array([0.81386733], dtype=float32),
#  array([0.8166206], dtype=float32)]

# %%
test.sample(2)
# Out:
#                      Consumption  Month  Year        Date      Time  Week  \
# DateTime
# 2021-12-26 17:30:00      12050.0     12  2021  2021-12-26  17:30:00     6
# 2021-12-26 19:30:00      12212.0     12  2021  2021-12-26  19:30:00     6
#
#                         Day
# DateTime
# 2021-12-26 17:30:00  Sunday
# 2021-12-26 19:30:00  Sunday

# %%
true_prediction = scaler.inverse_transform(test_prediction)

# %%
test['prediction'] = true_prediction
# Out:
# C:\Users\alisa\AppData\Local\Temp\ipykernel_24340\2961615516.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['prediction'] = true_prediction

# %%
test
# Out:
#                      Consumption  Month  Year        Date      Time  Week  \
# DateTime
# 2021-12-26 00:30:00      11936.0     12  2021  2021-12-26  00:30:00     6
# 2021-12-26 01:30:00      11659.0     12  2021  2021-12-26  01:30:00     6
# 2021-12-26 02:30:00      11964.0     12  2021  2021-12-26  02:30:00     6
# 2021-12-26 03:30:00      11875.0     12  2021  2021-12-26  03:30:00     6
# 2021-12-26 04:30:00      11558.0     12  2021  2021-12-26  04:30:00     6
# 2021-12-26 05:30:00      11252.0     12  2021  2021-12-26  05:30:00     6
# 2021-12-26 06:30:00      11151.0     12  2021  2021-12-26  06:30:00     6
# 2021-12-26 07:30:00      11165.0     12  2021  2021-12-26  07:30:00     6
# 2021-12-26 08:30:00      11206.0     12  2021  2021-12-26  08:30:00     6
# 2021-12-26 09:30:00      11296.0     12  2021  2021-12-26  09:30:00     6
# 2021-12-26 10:30:00      11477.0     12  2021  2021-12-26  10:30:00     6
# ...

# %%
test.plot()
# Out:
# <Axes: xlabel='DateTime'>

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

rmse = sqrt(mean_squared_error(test['Consumption'] , test['prediction']))

# %%
print(rmse)
# Out:
# 1035.079656321725

# %% [markdown]
# "The steady decrease and eventual stabilization of the loss indicates that the model training was effective, and we achieved a good fit for our energy consumption data with a final MSE of 3.02."

# %%
test_numeric.shape
test_numeric
# Out:
#                      Consumption
# DateTime
# 2021-12-26 00:30:00      11936.0
# 2021-12-26 01:30:00      11659.0
# 2021-12-26 02:30:00      11964.0
# 2021-12-26 03:30:00      11875.0
# 2021-12-26 04:30:00      11558.0
# 2021-12-26 05:30:00      11252.0
# 2021-12-26 06:30:00      11151.0
# 2021-12-26 07:30:00      11165.0
# 2021-12-26 08:30:00      11206.0
# 2021-12-26 09:30:00      11296.0
# 2021-12-26 10:30:00      11477.0
# 2021-12-26 11:30:00      11516.0
# 2021-12-26 12:30:00      11860.0
# 2021-12-26 13:30:00      12015.0
# 2021-12-26 14:30:00      12119.0
# 2021-12-26 15:30:00      12226.0
# 2021-12-26 16:30:00      12205.0
# 2021-12-26 17:30:00      12050.0
# 2021-12-26 18:30:00      12072.0
# 2021-12-26 19:30:00      12212.0
# 2021-12-26 20:30:00      12495.0
# 2021-12-26 21:30:00      12550.0
# 2021-12-26 22:30:00      12622.0
# 2021-12-26 23:30:00      12574.0

# %%
past_100_hour = pd.DataFrame(train_numeric[-100:])

# %%
test_df = pd.DataFrame(test_numeric)

# %%
import pandas as pd
final_df = pd.concat([past_100_hour, test_df], ignore_index=True)

# %%
final_df.head()
# Out:
#    Consumption
# 0      13196.0
# 1      13204.0
# 2      13175.0
# 3      13215.0
# 4      13030.0

# %%
input_data = scaler.fit_transform(final_df) # fit_transform() method will normalize the data based on the type of scaler(MinMaxScaler)
input_data
# Out:
# array([[0.98484848],
#        [0.98748353],
#        [0.97793149],
#        [0.99110672],
#        [0.93017128],
#        [0.79874835],
#        [0.81291173],
#        [0.74341238],
#        [0.60177866],
#        [0.51317523],
#        [0.45619236],
#        [0.43577075],
#        [0.45783926],
#        [0.57081686],
#        [0.78293808],
#        [0.91534914],
#        [1.        ],
#        [0.97628458],
#        [0.95981555],
#        [0.95487484],
#        [0.94038208],
#        [0.90612648],
#        [0.88965744],
#        [0.92951252],
#        [0.95948617],
#        [0.94993412],
#        [0.93741765],
#        [0.92819499],
#        [0.84617918],
#        [0.74110672],
#        [0.72496706],
#        [0.62318841],
#        [0.4726614 ],
#        [0.32674572],
#        [0.24505929],
#        [0.16765481],
#        [0.17588933],
#        [0.24374177],
#        [0.41205534],
#        [0.5102108 ],
#        [0.62088274],
#        [0.64690382],
#        [0.59156785],
# ...

# %%
input_data.shape
# Out:
# (124, 1)

# %%
x_test = []
y_test = []
for i in range(100, input_data.shape[0]): # The loop will start at row 100 and go until the last row (37041).
#In each iteration, a window of 100 consecutive rows (from i-100 to i) will be appended to x_test.
   x_test.append(input_data[i-100: i])
   y_test.append(input_data[i, 0])

# %%
x_test, y_test = np.array(x_test), np.array(y_test)
print(x_test.shape)
print(y_test.shape)
print(type(x_test))
# Out:
# (24, 100, 1)
# (24,)
# <class 'numpy.ndarray'>

# %%
# Making predictions

y_pred = model.predict(x_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step

# %%
y_pred.shape
# Out:
# (24, 1)

# %%
y_test
# Out:
# array([0.56982872, 0.47859025, 0.57905138, 0.5497365 , 0.44532279,
#        0.34453228, 0.31126482, 0.31587615, 0.32938076, 0.35902503,
#        0.41864295, 0.4314888 , 0.54479578, 0.5958498 , 0.6301054 ,
#        0.66534914, 0.65843215, 0.60737813, 0.61462451, 0.66073781,
#        0.75395257, 0.77206851, 0.79578393, 0.77997365])

# %%
y_pred
# Out:
# array([[0.6056724 ],
#        [0.53665745],
#        [0.42355305],
#        [0.58572155],
#        [0.56941783],
#        [0.3285855 ],
#        [0.32518774],
#        [0.3320191 ],
#        [0.336013  ],
#        [0.34567532],
#        [0.39801684],
#        [0.4670841 ],
#        [0.43118808],
#        [0.63913167],
#        [0.61905116],
#        [0.6626294 ],
#        [0.6725559 ],
#        [0.6477716 ],
#        [0.57166886],
#        [0.6585018 ],
#        [0.6754186 ],
#        [0.7871095 ],
#        [0.7534635 ],
#        [0.83544827]], dtype=float32)

# %%
scaler.scale_ # attribute represents how the data was scaled to fit within a given range
# Out:
# array([0.00032938])

# %%
# scale factor = 1/ standard daviation
scale_factor = 1/0.00985902 # the original standard deviation (before scaling) was  0.00985902, and now you're multiplying by the inverse to restore the original values.
y_pred = y_pred * scale_factor
y_test = y_test * scale_factor

# %%
plt.figure(figsize = (12,6))
plt.plot(y_test, 'b', label = "Original Electricity consumption" )
plt.plot(y_pred, 'r', label = "Predicted Electricity consumption")
plt.xlabel('Time')
plt.ylabel('Electricity consumptionin  MWh')
plt.legend()
plt.show()
from sklearn.metrics import mean_squared_error, mean_absolute_error

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f"Mean Squared Error: {mse:.2f}")
print(f"Mean Absolute Error: {mae:.2f}")
# Out:
# Mean Squared Error: 33.44
# Mean Absolute Error: 4.20

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
print("Mean absolute error on test set: ", mae)
# Out:
# Mean absolute error on test set:  4.198556683794749

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

# Plot the actual vs predicted values
plt.figure(figsize=(30, 30))
plt.plot(y_test, 'b', label="Original Electricity consumption")
plt.plot(y_pred, 'r', label="Predicted Electricity consumption")
plt.xlabel('Time')
plt.ylabel('Electricity consumption MWh')
plt.legend()
plt.show()

# Calculate error metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)  # RMSE is the square root of MSE
r2 = r2_score(y_test, y_pred)  # R^2 score

# Print the results
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"R^2 Score: {r2:.2f}")
# Out:
# Mean Squared Error (MSE): 33.44
# Mean Absolute Error (MAE): 4.20
# Root Mean Squared Error (RMSE): 5.78
# R^2 Score: 0.86
